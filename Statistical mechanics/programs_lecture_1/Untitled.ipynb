# %%
#%%writefile filename.py #write to py file in jupyter notebook
import random

n_trials = 4000
n_hits = 0
for iter in range(n_trials):
    x, y = random.uniform(-1.0, 1.0), random.uniform(-1.0, 1.0)
    if x**2 + y**2 < 1.0: 
        n_hits += 1
print(4.0 * n_hits / float(n_trials))
# Out:
# Writing filename.py

# %%
# %load filename.py   #load py file in jupyter notebook
import random

n_trials = 4000
n_hits = 0
for iter in range(n_trials):
    x, y = random.uniform(-1.0, 1.0), random.uniform(-1.0, 1.0)
    if x**2 + y**2 < 1.0: 
        n_hits += 1
print(4.0 * n_hits / float(n_trials))

# %%
# %%writefile direct_pi_multirun.py
import random
 
def direct_pi(N):
    n_hits = 0
    for i in range(N):
        x, y = random.uniform(-1.0, 1.0), random.uniform(-1.0, 1.0)
        if x ** 2 + y ** 2 < 1.0:
            n_hits += 1
    return n_hits
 
n_runs = 1000
n_trials = 4000
for run in range(n_runs):
    print (4.0 * direct_pi(n_trials) / float(n_trials))
# Out:
# Overwriting direct_pi_multirun.py

# %%
#same name file gets overwritten

# %%
# %load markov_pi.py
import random

x, y = 1.0, 1.0
delta = 0.1
n_trials = 100000
n_hits = 0
for i in range(n_trials):
    del_x, del_y = random.uniform(-delta, delta), random.uniform(-delta, delta)
    if abs(x + del_x) < 1.0 and abs(y + del_y) < 1.0:
        x, y = x + del_x, y + del_y
    if x**2 + y**2 < 1.0: n_hits += 1
print(4.0 * n_hits / float(n_trials))
# Out:
# 3.18952

# %%
# %load markov_pi_multirun.py
import random

def markov_pi(N, delta): 
    x, y = 1.0, 1.0
    n_hits = 0
    for i in range(N):
        del_x, del_y = random.uniform(-delta, delta), random.uniform(-delta, delta)
        if abs(x + del_x) < 1.0 and abs(y + del_y) < 1.0:
            x, y = x + del_x, y + del_y
        if x**2 + y**2 < 1.0: n_hits += 1
    return n_hits

n_runs = 1000
n_trials = 4000
delta = 0.1
for run in range(n_runs):
    print(4.0 * markov_pi(n_trials, delta) / float(n_trials))
# Out:
# 3.034
# 2.797
# 3.466
# 2.82
# 2.916
# 3.013
# 3.204
# 2.887
# 3.452
# 3.002
# 3.091
# 3.222
# 3.035
# 2.742
# 2.851
# 3.215
# 3.48
# 2.851
# 3.156
# 3.16
# 3.3
# 2.961
# 3.015
# 3.374
# 3.606
# 3.401
# 3.264
# 3.369
# 3.408
# 3.362
# 3.256
# 3.133
# 3.274
# 3.123
# 3.293
# 3.441
# 2.717
# 3.394
# 2.984
# 3.04
# 3.177
# 3.198
# 3.544
# 2.695
# 3.3
# 2.686
# 3.072
# 3.296
# 3.103
# 3.248
# 3.006
# 2.787
# 2.914
# 3.067
# 3.336
# 2.833
# 3.214
# 3.327
# 3.074
# 3.331
# 2.902
# 3.457
# 3.191
# 3.249
# 3.155
# 3.181
# 3.096
# 2.912
# 3.381
# 3.052
# 2.78
# 3.068
# 2.975
# 3.193
# 3.187
# 3.057
# 3.455
# 2.932
# 3.162
# 3.302
# 3.026
# 2.43
# 3.121
# 2.842
# 3.18
# 3.13
# 3.006
# 2.367
# 3.295
# 3.208
# 2.96
# 3.166
# 2.833
# 3.221
# 3.385
# 3.089
# 3.109
# 3.282
# 2.554
# 3.223
# 2.603
# 3.043
# 3.056
# 3.01
# 3.18
# 2.748
# 3.33
# 2.941
# 3.314
# 3.139
# 2.732
# 2.573
# 2.85
# 3.186
# 3.196
# 3.212
# 3.081
# 3.538
# 3.027
# 3.047
# 2.555
# 2.65
# 2.904
# 3.432
# 3.244
# 3.174
# 3.332
# ...

# %%
# %load pebble_basic.py
import random

neighbor =  [[1, 3, 0, 0], [2, 4, 0, 1], [2, 5, 1, 2],
             [4, 6, 3, 0], [5, 7, 3, 1], [5, 8, 4, 2],
             [7, 6, 6, 3], [8, 7, 6, 4], [8, 8, 7, 5]]
t_max = 4
site = 5
t = 0
print(site)
while t < t_max:
    t += 1
    print(neighbor[site])
    site = neighbor[site][random.randint(0, 3)]
    print(site)
# Out:
# 5
# [5, 8, 4, 2]
# 8
# [8, 8, 7, 5]
# 5
# [5, 8, 4, 2]
# 2
# [2, 5, 1, 2]
# 2

# %%
for i in range(10):                           #print in same line, spacebar for space and end=''for same line
    print(random.randint(0,3),"   ",end='')
# Out:
# 1    2    1    3    0    1    2    0    3    1

# %%
neighbor[8] #i=8 means ninth row
# Out:
# [8, 8, 7, 5]

# %%
# %load pebble_basic_inhomogeneous                          #.py not always needed if there's py file of same name
import random

histo = [0, 0, 0, 0, 0, 0, 0, 0, 0]
neighbor =  [[1, 3, 0, 0], [2, 4, 0, 1], [2, 5, 1, 2],
             [4, 6, 3, 0], [5, 7, 3, 1], [5, 8, 4, 2],
             [7, 6, 6, 3], [8, 7, 6, 4], [8, 8, 7, 5]]
weight = [3.0, 0.5, 1.0, 0.5, 1.0, 0.5, 2.0, 0.5, 1.0]
pos = 8
n_iter = 1000000
for iter in range(n_iter):
    new_pos = neighbor[pos][random.randint(0, 3)]
    if random.random() < weight[new_pos] / weight[pos]:
        pos = new_pos
    histo[pos] += 1 

norm = sum(weight)
print('comparison:  weight, histogram')
for k in range(9): 
    print ('site: ', k,' weight: ', weight[k], ' histo: ', norm * histo[k] / float(n_iter))
# Out:
# comparison:  weight, histogram
# site:  0  weight:  3.0  histo:  2.96609
# site:  1  weight:  0.5  histo:  0.49941
# site:  2  weight:  1.0  histo:  1.00433
# site:  3  weight:  0.5  histo:  0.49878
# site:  4  weight:  1.0  histo:  0.99632
# site:  5  weight:  0.5  histo:  0.50077
# site:  6  weight:  2.0  histo:  2.0425
# site:  7  weight:  0.5  histo:  0.5007
# site:  8  weight:  1.0  histo:  0.9911
